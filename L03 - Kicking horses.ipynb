# %% [markdown]
# ### Kicking horses
#
# A famous early  application of low-number statistics was an analysis of Prussian cavalryman horse-kick deaths by [Bortkiewicz](https://www.wikiwand.com/en/Ladislaus_Bortkiewicz) in 1898.
#
# He studied the distribution of 122 men kicked to death by horses among 10 Prussian army corps within 20 years (so a total number of corpes of 200). He recorded the number of corps with a given number of deaths:
#
# | Number of deaths | Number of groups |
# | --- | --- |
# | 0 | 109 |
# | 1 | 65 |
# | 2 | 22 |
# | 3 | 3 |
# | 4 | 1 |
#
# - Plot the resulting probability distribution. Careful with the normalization
# - How does it look like? Again try to fit it by hand.
#
# (Hint: think about sample mean and sample variance)

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
n_deaths = [0, 1, 2, 3, 4]
n_groups = [109, 65, 22, 3, 1]
n_tot = np.sum(n_groups)

probs = n_groups / n_tot 

plt.plot(n_deaths, probs, 'o')
plt.grid(alpha=0.3)
plt.xlabel('Number of deaths')
plt.ylabel('Prob. of the number of deaths')
# Out:
# Text(0, 0.5, 'Prob. of the number of deaths')

# %% [markdown]
# This looks like a Poisson distribution! We can try to fit it by hand:

# %%
mu_values = [0.1, 0.3, 0.5, 0.6, 1]

for mu in mu_values:
    model_probs = scipy.stats.poisson.pmf(n_deaths, mu)
    plt.plot(n_deaths, model_probs, label=f'$\mu$={mu}')

plt.plot(n_deaths, probs, 'o', c='C0')
plt.grid(alpha=0.3)
plt.xlabel('Number of deaths')
plt.ylabel('Prob. of the number of deaths')
plt.legend()

# %% [markdown]
# It looks like that the best fit is for $\mu \approx 0.6$. Let's see the exact value by using a sample mean:

# %%
best_mu = np.average(n_deaths, weights=n_groups)
best_fit  = scipy.stats.poisson.pmf(n_deaths, best_mu)

plt.plot(n_deaths, best_fit, c='C1', label=f'Best fit $\mu$={best_mu}')
plt.plot(n_deaths, probs, 'o', c='C0')
plt.grid(alpha=0.3)
plt.xlabel('Number of deaths')
plt.ylabel('Prob. of the number of deaths')
plt.legend()

# %% [markdown]
# Indeed, our best fit is a Poisson distribution with $\mu = 0.61$!
